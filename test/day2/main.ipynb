# %% [markdown]
# - File .RData là file dữ liệu nhị phân của ngôn ngữ R dùng để lưu 1 hay nhiều object trong môi trường làm việc
# - Object (Vector, Data frame, Matrix, List, Model, Function, Any)
# - load(<file .RData>)
# - Khi nào dùng: lưu toàn bộ workspace, lưu nhiều object cùng lúc, lưu state tạm thời
